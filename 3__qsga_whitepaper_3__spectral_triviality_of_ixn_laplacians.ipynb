# %% [markdown]
# # Quantum Spectral Graph Analysis - Whitepaper #3
#
# # Spectral Triviality of $IX_n$ Laplacians

# %% [markdown]
# Ohad Lev
#
# September 2025

# %% [markdown]
# -------------

# %% [markdown]
# ## (0) Imports

# %%
import numpy as np
from IPython.display import Math

from hamiltonian_generators import obtain_ix_n_hamiltonian
from util import compute_eigenspectrum_ixn_laplacian
from data_verifiers import is_valid_laplacian
from graphics import obtain_math_text_hermitian_spectrum, sparse_pauli_op_to_latex

# %% [markdown]
# ---

# %% [markdown]
# ## (1) Analytical Formula For $IX_n$ Graphs' Spectrum

# %% [markdown]
# In **[Lov75]**, it is proven how to analytically obtain the adjacency spectrum for "cube-like" graphs, which $IX_n$ graphs are apparently are:

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# By transforming this equation to work with the Laplacian eigenspectrum and adopting our notation so far, we obtain:

# %% [markdown]
# $$
#     \lambda(L, k) = d - \sum_{P \in S} (-1)^{m_k \cdot m_P}
#     \quad \forall \ k = 1, \dots, |V|
#     \tag{1}
# $$

# %% [markdown]
# Where:
#
# * $m_k$ is the binary representation of $k$.
# * $k$ is an index variable that take integer values from $1$ to $|V|$.
# * $S$ is the set of $IX$ operators that the Laplacian Hamiltonian is built from.
# * $P$ is a a single $IX$ operator in $S$.
# * $m_P$ is the *binary mask* of $P$, where $I \to 0$ and $X \to 1$. For example, $P = IXIX \implies m_P = 0101$.

# %% [markdown]
# Note that the order fo eigenvalues is not determined by $k$, as the next example shows.

# %% [markdown]
# ---------

# %% [markdown]
# ## (2) Experimentation

# %% [markdown]
# Let's try. We draw a random $IX_n$ Laplacian:

# %%
H = obtain_ix_n_hamiltonian(n=5, d=7)
Math("H = " + sparse_pauli_op_to_latex(H) + r"\tag{2}")
# Out:
# $\displaystyle H = 7 \, IIIII - IXXII - IIXII - IIXXI - IXIXX - XIIIX - IIIIX - IXIIX\tag{2}$

# %% [markdown]
# We compute its spectrum analitically, with **Equation (1)**:

# %%
H_spectrum = compute_eigenspectrum_ixn_laplacian(H)
Math(obtain_math_text_hermitian_spectrum(eigvals=H_spectrum))
# Out:
# $\displaystyle \lambda_{1} = 0.0, \ \\ \lambda_{2} = 8.0, \ \\ \lambda_{3} = 4.0, \ \\ \lambda_{4} = 8.0, \ \\ \lambda_{5} = 6.0, \ \\ \lambda_{6} = 14.0, \ \\ \lambda_{7} = 6.0, \ \\ \lambda_{8} = 10.0, \ \\ \lambda_{9} = 6.0, \ \lambda_{10} = 6.0, \ \lambda_{11} = 6.0, \ \\ \lambda_{12} = 10.0, \ \\ \lambda_{13} = 8.0, \ \lambda_{14} = 8.0, \ \\ \lambda_{15} = 4.0, \ \\ \lambda_{16} = 8.0, \ \\ \lambda_{17} = 2.0, \ \\ \lambda_{18} = 6.0, \ \lambda_{19} = 6.0, \ \lambda_{20} = 6.0, \ \\ \lambda_{21} = 8.0, \ \\ \lambda_{22} = 12.0, \ \\ \lambda_{23} = 8.0, \ \lambda_{24} = 8.0, \ \lambda_{25} = 8.0, \ \\ \lambda_{26} = 4.0, \ \\ \lambda_{27} = 8.0, \ \lambda_{28} = 8.0, \ \\ \lambda_{29} = 10.0, \ \\ \lambda_{30} = 6.0, \ \lambda_{31} = 6.0, \ \lambda_{32} = 6.0, \ $

# %% [markdown]
# It can be seen that the result is not sorted. We obtain also a sorted spectrum:

# %%
H_spectrum_sorted = compute_eigenspectrum_ixn_laplacian(H, sort=True)
Math(obtain_math_text_hermitian_spectrum(eigvals=H_spectrum_sorted))
# Out:
# $\displaystyle \lambda_{1} = 0.0, \ \\ \lambda_{2} = 2.0, \ \\ \lambda_{3} = 4.0, \ \lambda_{4} = 4.0, \ \lambda_{5} = 4.0, \ \\ \lambda_{6} = 6.0, \ \lambda_{7} = 6.0, \ \lambda_{8} = 6.0, \ \lambda_{9} = 6.0, \ \lambda_{10} = 6.0, \ \lambda_{11} = 6.0, \ \lambda_{12} = 6.0, \ \lambda_{13} = 6.0, \ \lambda_{14} = 6.0, \ \lambda_{15} = 6.0, \ \lambda_{16} = 6.0, \ \\ \lambda_{17} = 8.0, \ \lambda_{18} = 8.0, \ \lambda_{19} = 8.0, \ \lambda_{20} = 8.0, \ \lambda_{21} = 8.0, \ \lambda_{22} = 8.0, \ \lambda_{23} = 8.0, \ \lambda_{24} = 8.0, \ \lambda_{25} = 8.0, \ \lambda_{26} = 8.0, \ \lambda_{27} = 8.0, \ \\ \lambda_{28} = 10.0, \ \lambda_{29} = 10.0, \ \lambda_{30} = 10.0, \ \\ \lambda_{31} = 12.0, \ \\ \lambda_{32} = 14.0, \ $

# %% [markdown]
# And we compare this analytic result with a diagonalization result:

# %%
L = H.to_matrix()
L_eigendecomposition = np.linalg.eigh(L)
Math(obtain_math_text_hermitian_spectrum(eigh_result=L_eigendecomposition))
# Out:
# $\displaystyle \lambda_{1} = 0.0, \ \\ \lambda_{2} = 2.0, \ \\ \lambda_{3} = 4.0, \ \lambda_{4} = 4.0, \ \lambda_{5} = 4.0, \ \\ \lambda_{6} = 6.0, \ \lambda_{7} = 6.0, \ \lambda_{8} = 6.0, \ \lambda_{9} = 6.0, \ \lambda_{10} = 6.0, \ \lambda_{11} = 6.0, \ \lambda_{12} = 6.0, \ \lambda_{13} = 6.0, \ \lambda_{14} = 6.0, \ \lambda_{15} = 6.0, \ \lambda_{16} = 6.0, \ \\ \lambda_{17} = 8.0, \ \lambda_{18} = 8.0, \ \lambda_{19} = 8.0, \ \lambda_{20} = 8.0, \ \lambda_{21} = 8.0, \ \lambda_{22} = 8.0, \ \lambda_{23} = 8.0, \ \lambda_{24} = 8.0, \ \lambda_{25} = 8.0, \ \lambda_{26} = 8.0, \ \lambda_{27} = 8.0, \ \\ \lambda_{28} = 10.0, \ \lambda_{29} = 10.0, \ \lambda_{30} = 10.0, \ \\ \lambda_{31} = 12.0, \ \\ \lambda_{32} = 14.0, \ $

# %%
print(all(np.isclose(L_eigendecomposition.eigenvalues, H_spectrum_sorted)))
print(is_valid_laplacian(L))
# Out:
# True
# The matrix is a valid (weighted) Laplacian matrix
# True

# %% [markdown]
# We draw the corresponding graph:

# %%
import networkx as nx
from util import decompose_laplacian_matrix

_, _, A = decompose_laplacian_matrix(np.real(L))

graph = nx.from_numpy_array(A)
nx.draw(graph, with_labels=True)

# %% [markdown]
# -----

# %% [markdown]
# ## References

# %% [markdown]
# **[Lov75]** Lovász, László. "**Spectra of graphs with transitive groups.**" [Periodica Mathematica Hungarica 6.2 (1975): 191-195](https://link.springer.com/article/10.1007/BF02018821)
